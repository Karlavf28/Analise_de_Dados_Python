# %% [markdown]
# # Pandas
#
# + Pandas é uma biblioteca Python que fornece ferramentas de análise de dados e estruturas de dados de alta performance e fáceis de usar.
# + Pandas é construída sobre a biblioteca NumPy e sua estrutura de dados principal é chamada de **DataFrame**.
# + Um DataFrame permite que se armazene e se manipule tabelas de dados nas quais as linhas são as observações e as colunas as variáveis.

# %%
import pandas as pd # aqui importamos a biblioteca e damos a ela o "apelido" pd

# %% [markdown]
# Existem diversas formas de se criar um DataFrame

# %% [markdown]
# Usando dicionários

# %%
dic = {"country": ["Brazil", "Russia", "India", "China", "South Africa"],
       "capital": ["Brasilia", "Moscow", "New Dehli", "Beijing", "Pretoria"],
       "area": [8.516, 17.10, 3.286, 9.597, 1.221],
       "population": [200.4, 143.5, 1252, 1357, 52.98] }
brics = pd.DataFrame(dic)
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Dehli   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# O atributo **index** contém os títulos das linhas do DataFrame. Se no momento da criação do DataFrame nenhum índice for informado os índices são criados automaticamente a partir do 0.

# %%
print(brics.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# Os índices podem ser alterados a qualquer momento e com dados de quaisquer tipos.

# %%
brics.index = ["BR","RU","IN","CH","SA"]
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Dehli   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# O atributo **index** retorna uma visão dos títulos das linhas enquanto que o atributo **columns** retorna uma visão dos títulos das colunas.

# %%
print(brics.index)
print(brics.columns)
# Out:
# Index(['BR', 'RU', 'IN', 'CH', 'SA'], dtype='object')
# Index(['country', 'capital', 'area', 'population'], dtype='object')

# %% [markdown]
# Outra maneira de se criar um DataFrame é importando um arquivo csv

# %%
import pandas as pd
flavonoides = pd.read_csv("flavonoides.csv",sep='\t')
flavonoides
# Out:
#    Unnamed: 0       MW[2]      Sv[3]      Se[4]      Sp[5]       Ss[6]  Mv[7]  \
# 0        mol1  222.250000  19.010000  27.070000  19.719999   38.830002   0.70
# 1        mol2  238.250000  19.520000  28.400000  20.170000   44.500000   0.70
# 2        mol3  238.250000  19.520000  28.400000  20.170000   44.500000   0.70
# 3        mol4  252.279999  21.120001  31.280001  21.930000   44.000000   0.68
# 4        mol5  282.309998  23.230000  35.490002  24.150000   49.169998   0.66
# 5        mol6  312.339996  25.340000  39.709999  26.360001   54.330002   0.65
# 6        mol7  432.410004  32.099998  53.110001  33.160000   89.000000   0.63
# 7        mol8  286.250000  21.059999  32.380001  21.530001   61.500000   0.68
# 8        mol9  448.410004  32.610001  54.439999  33.610001   94.669998   0.63
# 5    72.050003   730.320007  362.579987   1.046      -4.17 -9.051
# 6    73.750000   749.119995  367.339996   1.180      -4.04 -8.995
# 7    78.519997   805.640015  410.380005   1.210      -4.25 -8.988
# 8    99.290001  1033.209961  546.479980   1.050      -4.35 -9.056
# 9    73.730003   746.000000  363.230011   0.560      -3.97 -8.620
# 10   73.730003   745.409973  365.239990   0.560      -3.95 -8.665
# 11   75.430000   764.929993  368.799988   0.280      -3.84 -8.595
# 12   80.199997   820.960022  410.040009   0.310      -4.06 -8.615
# 13   77.120003   784.590027  376.589996   1.150      -3.26 -8.554
# 14   77.120003   777.630005  367.910004   1.110      -2.92 -8.758
# 15   71.809998   756.530029  373.029999   2.590      -4.46 -9.120
# 16   71.809998   759.950012  387.549988   2.590      -4.29 -8.894
# 17   67.040001   705.640015  345.529999   2.560      -4.01 -9.240
# 18  106.000000  1103.699951  494.369995   4.120      -3.63 -8.835
# 19  143.410004  1507.030029  646.619995   0.640      -4.27 -9.104
#
#     Log (1/ID50)
# 0      -0.643453
# 1       0.698970
# 2      -0.544068
# 3      -0.954243
# 4       0.000000
# 5       1.000000
# 6      -0.380211
# 7       0.522879
# 8      -0.908485
# 9      -1.033424
# 10      0.537602
# 11     -0.380211
# 12      0.537602
# 13     -0.857332
# 14      0.096910
# 15     -0.977724
# 16      0.154902
# 17      0.221849
# 18     -0.113943
# 19      0.096910
#
# [20 rows x 557 columns]

# %% [markdown]
# Observem que o separador de colunas desse arquivo, tabulação, foi especificado por meio do parâmetro *sep='\t'*. Quando o separador das colunas é a vírgula esse parâmetro pode ser omitido.

# %% [markdown]
# Para que o comando interprete que a primeira coluna representa os índices, o parâmetro **index_col** deve ser acresentado.

# %%
flavonoides = pd.read_csv("flavonoides.csv",sep='\t',index_col=0)
flavonoides
# Out:
#             MW[2]      Sv[3]      Se[4]      Sp[5]       Ss[6]  Mv[7]  Me[8]  \
# mol1   222.250000  19.010000  27.070000  19.719999   38.830002   0.70   1.00
# mol2   238.250000  19.520000  28.400000  20.170000   44.500000   0.70   1.01
# mol3   238.250000  19.520000  28.400000  20.170000   44.500000   0.70   1.01
# mol4   252.279999  21.120001  31.280001  21.930000   44.000000   0.68   1.01
# mol5   282.309998  23.230000  35.490002  24.150000   49.169998   0.66   1.01
# mol6   312.339996  25.340000  39.709999  26.360001   54.330002   0.65   1.02
# mol7   432.410004  32.099998  53.110001  33.160000   89.000000   0.63   1.04
# mol8   286.250000  21.059999  32.380001  21.530001   61.500000   0.68   1.04
# mol9   448.410004  32.610001  54.439999  33.610001   94.669998   0.63   1.05
# mol10  372.399994  29.559999  48.130001  30.799999   64.669998   0.63   1.02
# mol11  238.250000  19.520000  28.400000  20.170000   44.500000   0.70   1.01
# mol12  268.279999  21.629999  32.610001  22.389999   49.669998   0.68   1.02
# mol13  286.250000  21.059999  32.380001  21.530001   61.500000   0.68   1.04
# mol9    99.290001  1033.209961  546.479980   1.050      -4.35 -9.056
# mol10   73.730003   746.000000  363.230011   0.560      -3.97 -8.620
# mol11   73.730003   745.409973  365.239990   0.560      -3.95 -8.665
# mol12   75.430000   764.929993  368.799988   0.280      -3.84 -8.595
# mol13   80.199997   820.960022  410.040009   0.310      -4.06 -8.615
# mol14   77.120003   784.590027  376.589996   1.150      -3.26 -8.554
# mol15   77.120003   777.630005  367.910004   1.110      -2.92 -8.758
# mol16   71.809998   756.530029  373.029999   2.590      -4.46 -9.120
# mol17   71.809998   759.950012  387.549988   2.590      -4.29 -8.894
# mol18   67.040001   705.640015  345.529999   2.560      -4.01 -9.240
# mol19  106.000000  1103.699951  494.369995   4.120      -3.63 -8.835
# mol20  143.410004  1507.030029  646.619995   0.640      -4.27 -9.104
#
#        Log (1/ID50)
# mol1      -0.643453
# mol2       0.698970
# mol3      -0.544068
# mol4      -0.954243
# mol5       0.000000
# mol6       1.000000
# mol7      -0.380211
# mol8       0.522879
# mol9      -0.908485
# mol10     -1.033424
# mol11      0.537602
# mol12     -0.380211
# mol13      0.537602
# mol14     -0.857332
# mol15      0.096910
# mol16     -0.977724
# mol17      0.154902
# mol18      0.221849
# mol19     -0.113943
# mol20      0.096910
#
# [20 rows x 556 columns]

# %% [markdown]
# Você pode visualizar apenas as primeiras linhas do DataFrame por meio do comando **head** ou apenas as últimas por meio do comando **tail**.

# %%
flavonoides.head()
# Out:
#            MW[2]      Sv[3]      Se[4]      Sp[5]      Ss[6]  Mv[7]  Me[8]  \
# mol1  222.250000  19.010000  27.070000  19.719999  38.830002   0.70   1.00
# mol2  238.250000  19.520000  28.400000  20.170000  44.500000   0.70   1.01
# mol3  238.250000  19.520000  28.400000  20.170000  44.500000   0.70   1.01
# mol4  252.279999  21.120001  31.280001  21.930000  44.000000   0.68   1.01
# mol5  282.309998  23.230000  35.490002  24.150000  49.169998   0.66   1.01
#
#       Mp[9]  Ms[10]  nAT[11]  ...        EHF           Eel           Enu  \
# mol1   0.73    2.28     27.0  ... -33.970001 -407011.25000  337425.40625
# mol2   0.72    2.47     28.0  ... -36.250000 -402533.03125  332944.90625
# mol3   0.72    2.47     28.0  ... -38.276001 -403063.68750  333473.59375
# mol4   0.71    2.32     31.0  ... -28.040001 -451991.59375  378824.31250
# mol5   0.69    2.34     35.0  ... -78.559998 -451691.59375  374712.09375
#
#              RM         Vol        �rea  Alog P  Mol Log S   Homo  \
# mol1  66.669998  690.150024  329.269989   2.030      -4.45 -9.154
# mol2  68.669998  690.500000  344.850006   2.030      -4.45 -9.028
# mol3  68.669998  691.250000  345.779999   2.030      -4.44 -9.356
# mol4  73.430000  751.099976  369.109985   2.070      -4.70 -9.231
# mol5  70.360001  708.479980  348.079987   1.075      -4.32 -9.227
#
#       Log (1/ID50)
# mol1     -0.643453
# mol2      0.698970
# mol3     -0.544068
# mol4     -0.954243
# mol5      0.000000
#
# [5 rows x 556 columns]

# %%
flavonoides.tail(2)
# Out:
#             MW[2]  Sv[3]      Se[4]      Sp[5]      Ss[6]  Mv[7]  Me[8]  \
# mol19  272.269989  21.15  32.939999  21.840000  55.000000   0.66   1.03
# mol20  302.299988  23.26  37.150002  24.059999  60.169998   0.65   1.03
#
#        Mp[9]  Ms[10]  nAT[11]  ...    EHF          Eel          Enu  \
# mol19   0.68    2.75     32.0  ... -435.0 -1264483.625  1107469.375
# mol20   0.67    2.73     36.0  ... -575.0 -1946337.750  1745783.875
#
#                RM          Vol        �rea  Alog P  Mol Log S   Homo  \
# mol19  106.000000  1103.699951  494.369995    4.12      -3.63 -8.835
# mol20  143.410004  1507.030029  646.619995    0.64      -4.27 -9.104
#
#        Log (1/ID50)
# mol19     -0.113943
# mol20      0.096910
#
# [2 rows x 556 columns]

# %% [markdown]
# Existem diversas maneiras de se acessar fatias (slices) de um DataFrame. A mais simples é usando colchetes, assim como é feito para listas e arrays.

# %%
flavonoides["MW[2]"] # acessando uma coluna
# Out:
# mol1     222.250000
# mol2     238.250000
# mol3     238.250000
# mol4     252.279999
# mol5     282.309998
# mol6     312.339996
# mol7     432.410004
# mol8     286.250000
# mol9     448.410004
# mol10    372.399994
# mol11    238.250000
# mol12    268.279999
# mol13    286.250000
# mol14    302.250000
# mol15    316.279999
# mol16    610.570007
# mol17    302.250000
# mol18    318.250000
# mol19    272.269989
# mol20    302.299988
# Name: MW[2], dtype: float64

# %%
flavonoides[["Lumo","Homo","Gap"]] # acessando uma lista de colunas
# Out:
#         Lumo   Homo    Gap
# mol1  -0.653 -9.154  8.501
# mol2  -0.803 -9.028  8.225
# mol3  -0.814 -9.356  8.542
# mol4  -0.365 -9.231  8.866
# mol5  -0.679 -9.227  8.548
# mol6  -0.702 -9.051  8.349
# mol7  -0.753 -8.995  8.242
# mol8  -0.704 -8.988  8.284
# mol9  -0.828 -9.056  8.228
# mol10 -0.751 -8.620  7.869
# mol11 -0.936 -8.665  7.729
# mol12 -0.822 -8.595  7.770
# mol13 -0.800 -8.615  7.815
# mol14 -0.926 -8.554  7.628
# mol15 -1.140 -8.758  7.618
# mol16 -0.347 -9.120  8.773
# mol17 -0.515 -8.894  8.380
# mol18 -0.460 -9.240  8.780
# mol19 -0.836 -8.835  7.990
# mol20 -0.426 -9.104  8.680

# %% [markdown]
# As linhas podem ser acessadas por meio da faixa de linhas desejadas entre colchetes.

# %%
flavonoides[2:5]
# Out:
#            MW[2]      Sv[3]      Se[4]  Sp[5]      Ss[6]  Mv[7]  Me[8]  Mp[9]  \
# mol3  238.250000  19.520000  28.400000  20.17  44.500000   0.70   1.01   0.72
# mol4  252.279999  21.120001  31.280001  21.93  44.000000   0.68   1.01   0.71
# mol5  282.309998  23.230000  35.490002  24.15  49.169998   0.66   1.01   0.69
#
#       Ms[10]  nAT[11]  ...        EHF           Eel           Enu         RM  \
# mol3    2.47     28.0  ... -38.276001 -403063.68750  333473.59375  68.669998
# mol4    2.32     31.0  ... -28.040001 -451991.59375  378824.31250  73.430000
# mol5    2.34     35.0  ... -78.559998 -451691.59375  374712.09375  70.360001
#
#              Vol        �rea  Alog P  Mol Log S   Homo  Log (1/ID50)
# mol3  691.250000  345.779999   2.030      -4.44 -9.356     -0.544068
# mol4  751.099976  369.109985   2.070      -4.70 -9.231     -0.954243
# mol5  708.479980  348.079987   1.075      -4.32 -9.227      0.000000
#
# [3 rows x 556 columns]

# %% [markdown]
# O método **loc** pode ser usado com dois índices e permite acessar linhas e colunas por meio dos respectivos títulos.

# %%
flavonoides.loc[:,["Lumo","Homo","Gap"]] # todas as linhas e algumas colunas
# Out:
#         Lumo   Homo    Gap
# mol1  -0.653 -9.154  8.501
# mol2  -0.803 -9.028  8.225
# mol3  -0.814 -9.356  8.542
# mol4  -0.365 -9.231  8.866
# mol5  -0.679 -9.227  8.548
# mol6  -0.702 -9.051  8.349
# mol7  -0.753 -8.995  8.242
# mol8  -0.704 -8.988  8.284
# mol9  -0.828 -9.056  8.228
# mol10 -0.751 -8.620  7.869
# mol11 -0.936 -8.665  7.729
# mol12 -0.822 -8.595  7.770
# mol13 -0.800 -8.615  7.815
# mol14 -0.926 -8.554  7.628
# mol15 -1.140 -8.758  7.618
# mol16 -0.347 -9.120  8.773
# mol17 -0.515 -8.894  8.380
# mol18 -0.460 -9.240  8.780
# mol19 -0.836 -8.835  7.990
# mol20 -0.426 -9.104  8.680

# %%
flavonoides.loc[["mol3","mol8","mol5","mol20"],:] # acessando algumas linhas e todas as colunas
# Out:
#             MW[2]      Sv[3]      Se[4]      Sp[5]      Ss[6]  Mv[7]  Me[8]  \
# mol3   238.250000  19.520000  28.400000  20.170000  44.500000   0.70   1.01
# mol8   286.250000  21.059999  32.380001  21.530001  61.500000   0.68   1.04
# mol5   282.309998  23.230000  35.490002  24.150000  49.169998   0.66   1.01
# mol20  302.299988  23.260000  37.150002  24.059999  60.169998   0.65   1.03
#
#        Mp[9]  Ms[10]  nAT[11]  ...         EHF           Eel           Enu  \
# mol3    0.72    2.47     28.0  ...  -38.276001 -4.030637e+05  3.334736e+05
# mol8    0.69    2.93     31.0  ... -160.619995 -5.855732e+05  4.902264e+05
# mol5    0.69    2.34     35.0  ...  -78.559998 -4.516916e+05  3.747121e+05
# mol20   0.67    2.73     36.0  ... -575.000000 -1.946338e+06  1.745784e+06
#
#                RM          Vol        �rea  Alog P  Mol Log S   Homo  \
# mol3    68.669998   691.250000  345.779999   2.030      -4.44 -9.356
# mol8    78.519997   805.640015  410.380005   1.210      -4.25 -8.988
# mol5    70.360001   708.479980  348.079987   1.075      -4.32 -9.227
# mol20  143.410004  1507.030029  646.619995   0.640      -4.27 -9.104
#
#        Log (1/ID50)
# mol3      -0.544068
# mol8       0.522879
# mol5       0.000000
# mol20      0.096910
#
# [4 rows x 556 columns]

# %%
flavonoides.loc[["mol3","mol8","mol5","mol20"],["Lumo","Homo","Gap"]] # acessando algumas linhas e algumas colunas
# Out:
#         Lumo   Homo    Gap
# mol3  -0.814 -9.356  8.542
# mol8  -0.704 -8.988  8.284
# mol5  -0.679 -9.227  8.548
# mol20 -0.426 -9.104  8.680

# %% [markdown]
# O método **iloc** pode ser usado de maneira semelhante ao método **loc**, exceto que ele utiliza como parâmetros os índices ao ínvés dos títulos das linhas ou colunas.

# %%
flavonoides.iloc[2] # passando apenas um parâmetro, a linha selecionada é acessada (mol3)
# Out:
# MW[2]           238.250000
# Sv[3]            19.520000
# Se[4]            28.400000
# Sp[5]            20.170000
# Ss[6]            44.500000
#                    ...
# �rea            345.779999
# Alog P            2.030000
# Mol Log S        -4.440000
# Homo             -9.356000
# Log (1/ID50)     -0.544068
# Name: mol3, Length: 556, dtype: float64

# %%
flavonoides.iloc[[2,5,8],551:555] # uma lista ou uma faixa de valores podem ser passados como parâmetros
# Out:
#             �rea  Alog P  Mol Log S   Homo
# mol3  345.779999   2.030      -4.44 -9.356
# mol6  362.579987   1.046      -4.17 -9.051
# mol9  546.479980   1.050      -4.35 -9.056

# %% [markdown]
# Assim como os arrays, os DataFrame também possuem os atributos **shape** e **size**

# %%
print(flavonoides.shape)
print(flavonoides.size)
# Out:
# (20, 556)
# 11120

# %% [markdown]
# O método **describe** fornece um resumo da estatística por colunas referente ao DataFrame

# %%
brics.describe()
# Out:
#             area   population
# count   5.000000     5.000000
# mean    7.944000   601.176000
# std     6.200557   645.261454
# min     1.221000    52.980000
# 25%     3.286000   143.500000
# 50%     8.516000   200.400000
# 75%     9.597000  1252.000000
# max    17.100000  1357.000000

# %% [markdown]
# No entanto, essas estatísticas podem ser obtidas individualmente por meio dos métodos mean, std, etc. Além disso é possível obter as estatísticas por linha especificando a dimensão desejada.

# %%
print(brics.mean())
print("-------------------------------")
print(brics.std(axis=1))
# Out:
# area            7.944
# population    601.176
# dtype: float64
# -------------------------------
# BR    135.682478
# RU     89.378297
# IN    882.974137
# CH    952.757798
# SA     36.599140
# dtype: float64

# %% [markdown]
# Os métodos **sum**, **min** e **max** também podem ser usados nos DataFrames.

# %%
print("Maior valor de cada coluna")
print(brics.max())
print("Soma dos valores de cada coluna numérica")
print(brics.sum(numeric_only=True))
print("Menor valor de cada linha")
print(brics.min(axis=1))
# Out:
# Maior valor de cada coluna
# country       South Africa
# capital           Pretoria
# area                  17.1
# population            1357
# dtype: object
# Soma dos valores de cada coluna numérica
# area            39.72
# population    3005.88
# dtype: float64
# Menor valor de cada linha
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# dtype: float64

# %% [markdown]
# Do mesmo modo que ocorre com os Arrays, o DataFrame transposto pode ser acessado por meio do atributo **T**.

# %%
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Dehli   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
brics.T
# Out:
#                   BR      RU         IN       CH            SA
# country       Brazil  Russia      India    China  South Africa
# capital     Brasilia  Moscow  New Dehli  Beijing      Pretoria
# area           8.516    17.1      3.286    9.597         1.221
# population     200.4   143.5       1252     1357         52.98

# %% [markdown]
# Você pode ordenar um DataFrame pelo título do índice com o método **sort_index** especificando qual dimensão será usada com a palavra chave *axis*.

# %%
brics.sort_index(axis=1,ascending=False) # ordenando as colunas pelo título em ordem decrescente
# Out:
#     population       country    capital    area
# BR      200.40        Brazil   Brasilia   8.516
# RU      143.50        Russia     Moscow  17.100
# IN     1252.00         India  New Dehli   3.286
# CH     1357.00         China    Beijing   9.597
# SA       52.98  South Africa   Pretoria   1.221

# %% [markdown]
# Você pode escolher uma linha ou coluna para ordenar o DataFrame com o método **sort_values**.

# %%
brics.sort_values(by="population",)
# Out:
#          country    capital    area  population
# SA  South Africa   Pretoria   1.221       52.98
# RU        Russia     Moscow  17.100      143.50
# BR        Brazil   Brasilia   8.516      200.40
# IN         India  New Dehli   3.286     1252.00
# CH         China    Beijing   9.597     1357.00

# %% [markdown]
# O método **concat** concatena as linhas de uma lista de DataFrames diferentes

# %%
df1 = brics[0:1]
print(df1)
df2 = brics[2:4]
print(df2)
pd.concat([df1,df2])
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4
#    country    capital   area  population
# IN   India  New Dehli  3.286      1252.0
# CH   China    Beijing  9.597      1357.0
#    country    capital   area  population
# BR  Brazil   Brasilia  8.516       200.4
# IN   India  New Dehli  3.286      1252.0
# CH   China    Beijing  9.597      1357.0

# %% [raw]
# Para concatenar colunas utilizamos o método **merge**.

# %%
df1 = brics.loc[:,["country","population"]]
print(df1)
df2 = brics.loc[:,["area"]]
print(df2)
df1.merge(df2,left_index=True,right_index=True)
# Out:
#          country  population
# BR        Brazil      200.40
# RU        Russia      143.50
# IN         India     1252.00
# CH         China     1357.00
# SA  South Africa       52.98
#       area
# BR   8.516
# RU  17.100
# IN   3.286
# CH   9.597
# SA   1.221
#          country  population    area
# BR        Brazil      200.40   8.516
# RU        Russia      143.50  17.100
# IN         India     1252.00   3.286
# CH         China     1357.00   9.597
# SA  South Africa       52.98   1.221

# %% [markdown]
# O DataFrame pode ser salvo em arquivo csv ou excel, por exemplo.

# %%
brics.to_csv("brics.csv")
brics.to_excel("brics.xlsx")

# %%
df = brics.T[2:]
df
# Out:
#                BR     RU     IN     CH     SA
# area        8.516   17.1  3.286  9.597  1.221
# population  200.4  143.5   1252   1357  52.98

# %%
brics['country']
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object
